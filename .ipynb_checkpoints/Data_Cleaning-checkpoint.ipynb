# %% [markdown]
# ## Getting Heartrate and Meditation Data
#
# ***NOTE - Headspace and Wearable device must be synced with Apple Health app in order to pull this data**
#
# In order to get the raw export, go into the “Apple Health” app, tap on your user icon and then select **“Export Health Data”**. This export process may take a few minutes, and, once completed, you should then have a filed called “export.zip”. You can share the file with yourself via AirDrop, Email or any other method.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import xml.etree.ElementTree as ET

# %%
#allow all columns to be seen. 
pd.set_option('display.max_columns', None)

# Source:https://stackoverflow.com/questions/47022070/display-all-dataframe-columns-in-a-jupyter-python-notebook/47022213

# %% [markdown]
# # Format the Apple Health XML file

# %% [markdown]
# #### Creating the Dataframe

# %%
tree = ET.parse('export.xml')
root = tree.getroot()

#Reference Docs: https://docs.python.org/3/library/xml.etree.elementtree.html

# %%
df = pd.DataFrame([child.attrib for child in root])
df.head()
# Out:
#                        value HKCharacteristicTypeIdentifierDateOfBirth  \
# 0  2020-12-01 18:59:42 -0500                                       NaN
# 1                        NaN
# 2                        193                                       NaN
# 3                        193                                       NaN
# 4                        193                                       NaN
#
#   HKCharacteristicTypeIdentifierBiologicalSex  \
# 0                                         NaN
# 1                       HKBiologicalSexNotSet
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#   HKCharacteristicTypeIdentifierBloodType  \
# 0                                     NaN
# 1                       HKBloodTypeNotSet
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#   HKCharacteristicTypeIdentifierFitzpatrickSkinType  \
# 0                                               NaN
# 1                       HKFitzpatrickSkinTypeNotSet
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
#
#   HKCharacteristicTypeIdentifierCardioFitnessMedicationsUse  \
# 0                                                NaN
# 1                                               None
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                type    sourceName sourceVersion unit  \
# 0                               NaN           NaN           NaN  NaN
# 1                               NaN           NaN           NaN  NaN
# 2  HKQuantityTypeIdentifierBodyMass  Orangetheory             1   lb
# 3  HKQuantityTypeIdentifierBodyMass  Orangetheory             1   lb
# 4  HKQuantityTypeIdentifierBodyMass  Orangetheory             1   lb
#
#                 creationDate                  startDate  \
# 0                        NaN                        NaN
# 1                        NaN                        NaN
# 2  2020-01-03 18:16:18 -0500  2020-01-03 18:16:18 -0500
# 3  2020-01-07 02:00:23 -0500  2020-01-07 02:00:23 -0500
# 4  2020-01-11 14:24:53 -0500  2020-01-11 14:24:53 -0500
#
#                      endDate device workoutActivityType duration durationUnit  \
# 0                        NaN    NaN                 NaN      NaN          NaN
# 1                        NaN    NaN                 NaN      NaN          NaN
# 2  2020-01-03 18:16:18 -0500    NaN                 NaN      NaN          NaN
# 3  2020-01-07 02:00:23 -0500    NaN                 NaN      NaN          NaN
# 4  2020-01-11 14:24:53 -0500    NaN                 NaN      NaN          NaN
#
#   totalDistance totalDistanceUnit totalEnergyBurned totalEnergyBurnedUnit
# 0           NaN               NaN               NaN                   NaN
# 1           NaN               NaN               NaN                   NaN
# 2           NaN               NaN               NaN                   NaN
# 3           NaN               NaN               NaN                   NaN
# 4           NaN               NaN               NaN                   NaN

# %%
df.shape
# Out:
# (104137, 21)

# %% [markdown]
# ### Clean the Dataframe to only have Heartrate and Meditation Data

# %%
df['sourceName'].value_counts() #count of each sourceName
# Out:
# Josh’s Iphone    74620
# Connect          27235
# Peloton           1160
# Strava             333
# Orangetheory       327
# Clock              278
# Headspace          152
# Jour                29
# Health               1
# Name: sourceName, dtype: int64

# %% [markdown]
# #### Filter to sources of Connect (my Garmin watch), Headspace, and only heartrate data

# %%
df = df[((df['sourceName'] == "Connect") & (df["type"] == "HKQuantityTypeIdentifierHeartRate")) | (df['sourceName'] == "Headspace")].copy()

# %% [markdown]
# #### Drop unnecessary columns

# %%
df.drop(columns=['HKCharacteristicTypeIdentifierDateOfBirth',
       'HKCharacteristicTypeIdentifierBiologicalSex',
       'HKCharacteristicTypeIdentifierBloodType',
       'HKCharacteristicTypeIdentifierFitzpatrickSkinType',
       'HKCharacteristicTypeIdentifierCardioFitnessMedicationsUse', 'sourceVersion','creationDate',
       'device', 'workoutActivityType', 'duration', 'durationUnit',
       'totalDistance', 'totalDistanceUnit', 'totalEnergyBurned',
       'totalEnergyBurnedUnit'], inplace=True)

# %% [markdown]
# #### Check the data types

# %%
df.dtypes
# Out:
# value         object
# type          object
# sourceName    object
# unit          object
# startDate     object
# endDate       object
# dtype: object

# %%
#Convert datatypes
df['value'] = df.value.astype(float)
df['startDate'] = pd.to_datetime(df['startDate'])
df['endDate'] = pd.to_datetime(df['endDate'])

# %%
df.dtypes
# Out:
# value                                        float64
# type                                          object
# sourceName                                    object
# unit                                          object
# startDate     datetime64[ns, pytz.FixedOffset(-300)]
# endDate       datetime64[ns, pytz.FixedOffset(-300)]
# dtype: object

# %% [markdown]
# ## Export Data as a .CSV

# %%
df.to_csv('clean_data.csv',index=False)

# %%
df[df['sourceName'] == 'Headspace']['startDate'].groupby(df.startDate.dt.month).agg('count').plot()
# Out:
# <AxesSubplot:xlabel='startDate'>

# %%
df[df['sourceName'] == 'Connect']['startDate'].groupby(df.startDate.dt.month).agg('count').plot()
# Out:
# <AxesSubplot:xlabel='startDate'>

# %% [markdown]
# # Exploratory Data Analysis
#
# We will be investigating the month of November since we have incomplete Heartrate data for the other months in the analysis

# %%
nov = df[(df['startDate'] >= '2020-11-01') & (df['startDate'] < '2020-12-01')].copy()
nov.head()
# Out:
#       value                               type sourceName       unit  \
# 4091   94.0  HKQuantityTypeIdentifierHeartRate    Connect  count/min
# 4092   66.0  HKQuantityTypeIdentifierHeartRate    Connect  count/min
# 4093   64.0  HKQuantityTypeIdentifierHeartRate    Connect  count/min
# 4094   60.0  HKQuantityTypeIdentifierHeartRate    Connect  count/min
# 4095   63.0  HKQuantityTypeIdentifierHeartRate    Connect  count/min
#
#                      startDate                   endDate
# 4091 2020-11-01 23:58:00-05:00 2020-11-01 23:58:00-05:00
# 4092 2020-11-01 23:56:00-05:00 2020-11-01 23:56:00-05:00
# 4093 2020-11-01 23:54:00-05:00 2020-11-01 23:54:00-05:00
# 4094 2020-11-01 23:52:00-05:00 2020-11-01 23:52:00-05:00
# 4095 2020-11-01 23:50:00-05:00 2020-11-01 23:50:00-05:00

# %%
nov.shape
# Out:
# (20910, 6)

# %% [markdown]
# ### Create a function to add a `headspace_session` column for Headspace meditations

# %%
def addSessions(dataframe):
    sessions = [] #create a list to store the session numbers
    session_count = 0 #create a counter for sessions

    for source in dataframe['sourceName']:
        if source == 'Headspace':
            session_count += 1
            sessions.append(session_count)
        else:
            sessions.append(0) #if Connect, set session as 0
    
    return sessions

# %%
#Add a column called headspace_session

nov['headspace_session'] = addSessions(nov)

# %%
nov[nov['sourceName'] == 'Headspace']
# Out:
#         value                                    type sourceName unit  \
# 103423    NaN  HKCategoryTypeIdentifierMindfulSession  Headspace  NaN
# 103424    NaN  HKCategoryTypeIdentifierMindfulSession  Headspace  NaN
# 103425    NaN  HKCategoryTypeIdentifierMindfulSession  Headspace  NaN
# 103426    NaN  HKCategoryTypeIdentifierMindfulSession  Headspace  NaN
# 103427    NaN  HKCategoryTypeIdentifierMindfulSession  Headspace  NaN
# 103428    NaN  HKCategoryTypeIdentifierMindfulSession  Headspace  NaN
# 103429    NaN  HKCategoryTypeIdentifierMindfulSession  Headspace  NaN
# 103430    NaN  HKCategoryTypeIdentifierMindfulSession  Headspace  NaN
# 103431    NaN  HKCategoryTypeIdentifierMindfulSession  Headspace  NaN
# 103432    NaN  HKCategoryTypeIdentifierMindfulSession  Headspace  NaN
# 103433    NaN  HKCategoryTypeIdentifierMindfulSession  Headspace  NaN
# 103434    NaN  HKCategoryTypeIdentifierMindfulSession  Headspace  NaN
#
#                        startDate                   endDate  headspace_session
# 103423 2020-11-04 13:27:25-05:00 2020-11-04 13:36:21-05:00                  1
# 103424 2020-11-04 21:56:14-05:00 2020-11-04 21:59:16-05:00                  2
# 103425 2020-11-09 00:12:38-05:00 2020-11-09 00:24:08-05:00                  3
# 103426 2020-11-10 16:49:36-05:00 2020-11-10 16:56:38-05:00                  4
# 103427 2020-11-11 01:35:05-05:00 2020-11-11 01:46:35-05:00                  5
# 103428 2020-11-16 14:39:35-05:00 2020-11-16 14:41:38-05:00                  6
# 103429 2020-11-16 14:42:00-05:00 2020-11-16 14:49:57-05:00                  7
# 103430 2020-11-19 02:36:28-05:00 2020-11-19 02:38:43-05:00                  8
# 103431 2020-11-24 01:59:39-05:00 2020-11-24 02:02:40-05:00                  9
# 103432 2020-11-24 23:46:54-05:00 2020-11-24 23:56:40-05:00                 10
# 103433 2020-11-29 01:31:47-05:00 2020-11-29 01:43:17-05:00                 11
# 103434 2020-11-29 23:50:48-05:00 2020-11-29 23:56:03-05:00                 12

# %% [markdown]
# ### Link the Connect Heartrate data to a `headspace_session`

# %%
#create a dataframe of just the headspace sessions
headspace_sessions = nov[nov['sourceName'] == 'Headspace'].copy()

# %%
headspace_sessions
# Out:
#         value                                    type sourceName unit  \
# 103423    NaN  HKCategoryTypeIdentifierMindfulSession  Headspace  NaN
# 103424    NaN  HKCategoryTypeIdentifierMindfulSession  Headspace  NaN
# 103425    NaN  HKCategoryTypeIdentifierMindfulSession  Headspace  NaN
# 103426    NaN  HKCategoryTypeIdentifierMindfulSession  Headspace  NaN
# 103427    NaN  HKCategoryTypeIdentifierMindfulSession  Headspace  NaN
# 103428    NaN  HKCategoryTypeIdentifierMindfulSession  Headspace  NaN
# 103429    NaN  HKCategoryTypeIdentifierMindfulSession  Headspace  NaN
# 103430    NaN  HKCategoryTypeIdentifierMindfulSession  Headspace  NaN
# 103431    NaN  HKCategoryTypeIdentifierMindfulSession  Headspace  NaN
# 103432    NaN  HKCategoryTypeIdentifierMindfulSession  Headspace  NaN
# 103433    NaN  HKCategoryTypeIdentifierMindfulSession  Headspace  NaN
# 103434    NaN  HKCategoryTypeIdentifierMindfulSession  Headspace  NaN
#
#                        startDate                   endDate  headspace_session
# 103423 2020-11-04 13:27:25-05:00 2020-11-04 13:36:21-05:00                  1
# 103424 2020-11-04 21:56:14-05:00 2020-11-04 21:59:16-05:00                  2
# 103425 2020-11-09 00:12:38-05:00 2020-11-09 00:24:08-05:00                  3
# 103426 2020-11-10 16:49:36-05:00 2020-11-10 16:56:38-05:00                  4
# 103427 2020-11-11 01:35:05-05:00 2020-11-11 01:46:35-05:00                  5
# 103428 2020-11-16 14:39:35-05:00 2020-11-16 14:41:38-05:00                  6
# 103429 2020-11-16 14:42:00-05:00 2020-11-16 14:49:57-05:00                  7
# 103430 2020-11-19 02:36:28-05:00 2020-11-19 02:38:43-05:00                  8
# 103431 2020-11-24 01:59:39-05:00 2020-11-24 02:02:40-05:00                  9
# 103432 2020-11-24 23:46:54-05:00 2020-11-24 23:56:40-05:00                 10
# 103433 2020-11-29 01:31:47-05:00 2020-11-29 01:43:17-05:00                 11
# 103434 2020-11-29 23:50:48-05:00 2020-11-29 23:56:03-05:00                 12

# %%
linked_session = []                                                                              #create a list to save the sessions

for row in nov.itertuples():                                                                     #for every row in november
    session_matches = []
    for session in headspace_sessions.itertuples():                                              #loop through the headspace sessions
        if (row[5] >= session[5]) and (row[5] <= session[6] and (row[3] == 'Connect')):          #if the heartrate data is inbetween a headspace session
            session_matches.append(session[-1])                                                  #append the session
        else:
            session_matches.append(0)                                                            #append 0 if the heartrate period does not match a headspace session
    
    linked_session.append(sum(session_matches))

# %% [markdown]
# #### Create a new column called `linked_session`

# %%
nov['linked_session'] = linked_session

# %%
nov
# Out:
#         value                                    type sourceName       unit  \
# 4091     94.0       HKQuantityTypeIdentifierHeartRate    Connect  count/min
# 4092     66.0       HKQuantityTypeIdentifierHeartRate    Connect  count/min
# 4093     64.0       HKQuantityTypeIdentifierHeartRate    Connect  count/min
# 4094     60.0       HKQuantityTypeIdentifierHeartRate    Connect  count/min
# 4095     63.0       HKQuantityTypeIdentifierHeartRate    Connect  count/min
# ...       ...                                     ...        ...        ...
# 103430    NaN  HKCategoryTypeIdentifierMindfulSession  Headspace        NaN
# 103431    NaN  HKCategoryTypeIdentifierMindfulSession  Headspace        NaN
# 103432    NaN  HKCategoryTypeIdentifierMindfulSession  Headspace        NaN
# 103433    NaN  HKCategoryTypeIdentifierMindfulSession  Headspace        NaN
# 103434    NaN  HKCategoryTypeIdentifierMindfulSession  Headspace        NaN
#
#                        startDate                   endDate  headspace_session  \
# 4091   2020-11-01 23:58:00-05:00 2020-11-01 23:58:00-05:00                  0
# 4092   2020-11-01 23:56:00-05:00 2020-11-01 23:56:00-05:00                  0
# 4093   2020-11-01 23:54:00-05:00 2020-11-01 23:54:00-05:00                  0
# 4094   2020-11-01 23:52:00-05:00 2020-11-01 23:52:00-05:00                  0
# 4095   2020-11-01 23:50:00-05:00 2020-11-01 23:50:00-05:00                  0
# ...                          ...                       ...                ...
# 103430 2020-11-19 02:36:28-05:00 2020-11-19 02:38:43-05:00                  8
# 103431 2020-11-24 01:59:39-05:00 2020-11-24 02:02:40-05:00                  9
# 103432 2020-11-24 23:46:54-05:00 2020-11-24 23:56:40-05:00                 10
# 103433 2020-11-29 01:31:47-05:00 2020-11-29 01:43:17-05:00                 11
# 103434 2020-11-29 23:50:48-05:00 2020-11-29 23:56:03-05:00                 12
#
#         linked_session
# 4091                 0
# 4092                 0
# 4093                 0
# 4094                 0
# 4095                 0
# ...                ...
# 103430               0
# 103431               0
# 103432               0
# 103433               0
# 103434               0
#
# [20910 rows x 8 columns]

# %% [markdown]
# # Export to a .CSV

# %%
nov.to_csv('nov_data.csv',index=False)

# %%
nov[nov['linked_session'] != 0].sort_values('startDate')
# Out:
#        value                               type sourceName       unit  \
# 6521    92.0  HKQuantityTypeIdentifierHeartRate    Connect  count/min
# 6520   136.0  HKQuantityTypeIdentifierHeartRate    Connect  count/min
# 6519   118.0  HKQuantityTypeIdentifierHeartRate    Connect  count/min
# 6518   108.0  HKQuantityTypeIdentifierHeartRate    Connect  count/min
# 6517   120.0  HKQuantityTypeIdentifierHeartRate    Connect  count/min
# 6266    57.0  HKQuantityTypeIdentifierHeartRate    Connect  count/min
# 9063    62.0  HKQuantityTypeIdentifierHeartRate    Connect  count/min
# 9062    64.0  HKQuantityTypeIdentifierHeartRate    Connect  count/min
# 9061    49.0  HKQuantityTypeIdentifierHeartRate    Connect  count/min
# 9060    50.0  HKQuantityTypeIdentifierHeartRate    Connect  count/min
# 9059    62.0  HKQuantityTypeIdentifierHeartRate    Connect  count/min
# 9058    52.0  HKQuantityTypeIdentifierHeartRate    Connect  count/min
# 10704   85.0  HKQuantityTypeIdentifierHeartRate    Connect  count/min
# 10703   68.0  HKQuantityTypeIdentifierHeartRate    Connect  count/min
# 10702   60.0  HKQuantityTypeIdentifierHeartRate    Connect  count/min
# 10701   58.0  HKQuantityTypeIdentifierHeartRate    Connect  count/min
# 10441   88.0  HKQuantityTypeIdentifierHeartRate    Connect  count/min
# 10440   86.0  HKQuantityTypeIdentifierHeartRate    Connect  count/min
# 10439   48.0  HKQuantityTypeIdentifierHeartRate    Connect  count/min
# 10438   49.0  HKQuantityTypeIdentifierHeartRate    Connect  count/min
# 10437   49.0  HKQuantityTypeIdentifierHeartRate    Connect  count/min
# 10436   51.0  HKQuantityTypeIdentifierHeartRate    Connect  count/min
# 14904   87.0  HKQuantityTypeIdentifierHeartRate    Connect  count/min
# 14903   78.0  HKQuantityTypeIdentifierHeartRate    Connect  count/min
# 14902   72.0  HKQuantityTypeIdentifierHeartRate    Connect  count/min
# 14901   52.0  HKQuantityTypeIdentifierHeartRate    Connect  count/min
# 14900   43.0  HKQuantityTypeIdentifierHeartRate    Connect  count/min
# 15951   80.0  HKQuantityTypeIdentifierHeartRate    Connect  count/min
# 20680   62.0  HKQuantityTypeIdentifierHeartRate    Connect  count/min
# 20679   54.0  HKQuantityTypeIdentifierHeartRate    Connect  count/min
# 20032   82.0  HKQuantityTypeIdentifierHeartRate    Connect  count/min
# 20031   59.0  HKQuantityTypeIdentifierHeartRate    Connect  count/min
# 20030   58.0  HKQuantityTypeIdentifierHeartRate    Connect  count/min
# 20029   53.0  HKQuantityTypeIdentifierHeartRate    Connect  count/min
# 20028   53.0  HKQuantityTypeIdentifierHeartRate    Connect  count/min
# 24229   64.0  HKQuantityTypeIdentifierHeartRate    Connect  count/min
# 24228   62.0  HKQuantityTypeIdentifierHeartRate    Connect  count/min
# 24227   52.0  HKQuantityTypeIdentifierHeartRate    Connect  count/min
# 24226   49.0  HKQuantityTypeIdentifierHeartRate    Connect  count/min
# 24225   47.0  HKQuantityTypeIdentifierHeartRate    Connect  count/min
# 24224   44.0  HKQuantityTypeIdentifierHeartRate    Connect  count/min
# 23577   73.0  HKQuantityTypeIdentifierHeartRate    Connect  count/min
# 23576   56.0  HKQuantityTypeIdentifierHeartRate    Connect  count/min
# 23575   55.0  HKQuantityTypeIdentifierHeartRate    Connect  count/min
#
#                       startDate                   endDate  headspace_session  \
# 6521  2020-11-04 13:28:00-05:00 2020-11-04 13:28:00-05:00                  0
# 6520  2020-11-04 13:30:00-05:00 2020-11-04 13:30:00-05:00                  0
# 6519  2020-11-04 13:32:00-05:00 2020-11-04 13:32:00-05:00                  0
# 6518  2020-11-04 13:34:00-05:00 2020-11-04 13:34:00-05:00                  0
# 6517  2020-11-04 13:36:00-05:00 2020-11-04 13:36:00-05:00                  0
# 6266  2020-11-04 21:58:00-05:00 2020-11-04 21:58:00-05:00                  0
# 9063  2020-11-09 00:14:00-05:00 2020-11-09 00:14:00-05:00                  0
# 9062  2020-11-09 00:16:00-05:00 2020-11-09 00:16:00-05:00                  0
# 9061  2020-11-09 00:18:00-05:00 2020-11-09 00:18:00-05:00                  0
# 9060  2020-11-09 00:20:00-05:00 2020-11-09 00:20:00-05:00                  0
# 9059  2020-11-09 00:22:00-05:00 2020-11-09 00:22:00-05:00                  0
# 9058  2020-11-09 00:24:00-05:00 2020-11-09 00:24:00-05:00                  0
# 10704 2020-11-10 16:50:00-05:00 2020-11-10 16:50:00-05:00                  0
# 10703 2020-11-10 16:52:00-05:00 2020-11-10 16:52:00-05:00                  0
# 10702 2020-11-10 16:54:00-05:00 2020-11-10 16:54:00-05:00                  0
# 10701 2020-11-10 16:56:00-05:00 2020-11-10 16:56:00-05:00                  0
# 10441 2020-11-11 01:36:00-05:00 2020-11-11 01:36:00-05:00                  0
# 10440 2020-11-11 01:38:00-05:00 2020-11-11 01:38:00-05:00                  0
# 10439 2020-11-11 01:40:00-05:00 2020-11-11 01:40:00-05:00                  0
# 10438 2020-11-11 01:42:00-05:00 2020-11-11 01:42:00-05:00                  0
# 10437 2020-11-11 01:44:00-05:00 2020-11-11 01:44:00-05:00                  0
# 10436 2020-11-11 01:46:00-05:00 2020-11-11 01:46:00-05:00                  0
# 14904 2020-11-16 14:40:00-05:00 2020-11-16 14:40:00-05:00                  0
# 14903 2020-11-16 14:42:00-05:00 2020-11-16 14:42:00-05:00                  0
# 14902 2020-11-16 14:44:00-05:00 2020-11-16 14:44:00-05:00                  0
# 14901 2020-11-16 14:46:00-05:00 2020-11-16 14:46:00-05:00                  0
# 14900 2020-11-16 14:48:00-05:00 2020-11-16 14:48:00-05:00                  0
# 15951 2020-11-19 02:38:00-05:00 2020-11-19 02:38:00-05:00                  0
# 20680 2020-11-24 02:00:00-05:00 2020-11-24 02:00:00-05:00                  0
# 20679 2020-11-24 02:02:00-05:00 2020-11-24 02:02:00-05:00                  0
# 20032 2020-11-24 23:48:00-05:00 2020-11-24 23:48:00-05:00                  0
# 20031 2020-11-24 23:50:00-05:00 2020-11-24 23:50:00-05:00                  0
# 20030 2020-11-24 23:52:00-05:00 2020-11-24 23:52:00-05:00                  0
# 20029 2020-11-24 23:54:00-05:00 2020-11-24 23:54:00-05:00                  0
# 20028 2020-11-24 23:56:00-05:00 2020-11-24 23:56:00-05:00                  0
# 24229 2020-11-29 01:32:00-05:00 2020-11-29 01:32:00-05:00                  0
# 24228 2020-11-29 01:34:00-05:00 2020-11-29 01:34:00-05:00                  0
# 24227 2020-11-29 01:36:00-05:00 2020-11-29 01:36:00-05:00                  0
# 24226 2020-11-29 01:38:00-05:00 2020-11-29 01:38:00-05:00                  0
# 24225 2020-11-29 01:40:00-05:00 2020-11-29 01:40:00-05:00                  0
# 24224 2020-11-29 01:42:00-05:00 2020-11-29 01:42:00-05:00                  0
# 23577 2020-11-29 23:52:00-05:00 2020-11-29 23:52:00-05:00                  0
# 23576 2020-11-29 23:54:00-05:00 2020-11-29 23:54:00-05:00                  0
# 23575 2020-11-29 23:56:00-05:00 2020-11-29 23:56:00-05:00                  0
#
#        linked_session
# 6521                1
# 6520                1
# 6519                1
# 6518                1
# 6517                1
# 6266                2
# 9063                3
# 9062                3
# 9061                3
# 9060                3
# 9059                3
# 9058                3
# 10704               4
# 10703               4
# 10702               4
# 10701               4
# 10441               5
# 10440               5
# 10439               5
# 10438               5
# 10437               5
# 10436               5
# 14904               6
# 14903               7
# 14902               7
# 14901               7
# 14900               7
# 15951               8
# 20680               9
# 20679               9
# 20032              10
# 20031              10
# 20030              10
# 20029              10
# 20028              10
# 24229              11
# 24228              11
# 24227              11
# 24226              11
# 24225              11
# 24224              11
# 23577              12
# 23576              12
# 23575              12
